# %% [markdown]
# Install Python Sql library

# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: six in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: prettytable<1 in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: sqlparse in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.4.1)
# Requirement already satisfied: ipython>=1.0 in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (7.19.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.3.20)
# Requirement already satisfied: decorator in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.4.2)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (50.3.1.post20201107)
# Requirement already satisfied: pygments in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (2.7.2)
# Requirement already satisfied: backcall in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.17.2)
# Requirement already satisfied: traitlets>=4.2 in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.0.5)
# Requirement already satisfied: pickleshare in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (3.0.8)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=1.0->ipython-sql) (0.6.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/dylannakahara/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)

# %% [markdown]
# Load SQL Extension

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# Connect to sql_final_project database

# %%
# %sql mysql://USERNAME:PASSWORD@HOST/DATABASE

# %% [markdown]
# Check Connection and SQL import

# %%
# %%sql
# SELECT *
# FROM wealthy_zip
# Out:
#  * mysql://admin:***@dnaka-sql-final.c8e00slqxvtw.us-east-1.rds.amazonaws.com/sql_final_project
# 200 rows affected.
# [(1, 'Victoriya Berezina', 'General Dentist', '4 out of 5 stars rating', ' 0.8 mi', '1300 University Dr Ste 1', 'Menlo Park ', 'CA ', '94025', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (2, 'Divian Patel', 'General Dentist', '4 out of 5 stars rating', ' 0.8 mi', '1300 University Dr Ste 5', 'Menlo Park ', 'CA ', '94025', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (3, 'Trishal Lamba', 'General Dentist', '4 out of 5 stars rating', ' 0.8 mi', '1300 University Dr Ste 7', 'Menlo Park ', 'CA ', '94025', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (4, 'Negar Parravi', 'General Dentist', '4 out of 5 stars rating', ' 0.8 mi', '1300 University Dr Ste 3', 'Menlo Park ', 'CA ', '94025', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (5, 'Elizabeth Doi', 'General Dentist', '4 out of 5 stars rating', ' 0.8 mi', '888 Oak Grove Ave Ste 1', 'Menlo Park ', 'CA ', '94025', 'Delta Dental Premier', ''),
#  (6, 'Yekta Rafaty', 'General Dentist', '4 out of 5 stars rating', ' 0.8 mi', '888 Oak Grove Ave Ste 2', 'Menlo Park ', 'CA ', '94025', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (7, 'Joseph Sarkosh', 'General Dentist', '4 out of 5 stars rating', ' 0.8 mi', '888 Oak Grove Ave Ste 6', 'Menlo Park ', 'CA ', '94025', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (8, 'Arthur Jollymour', 'General Dentist', '4 out of 5 stars rating', ' 0.8 mi', '888 Oak Grove Ave Ste 3', 'Menlo Park ', 'CA ', '94025', 'Delta Dental Premier', ''),
#  (9, 'Jay Gu', 'General Dentist', ' ', ' 0.8 mi', '888 Oak Grove Ave Ste 2', 'Menlo Park ', 'CA ', '94025', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (10, 'Lucy Hua', 'General Dentist', ' ', ' 0.8 mi', '888 Oak Grove Ave Ste 2', 'Menlo Park ', 'CA ', '94025', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (11, 'Richard Kitasoe', 'General Dentist', '4 out of 5 stars rating', ' 0.9 mi', '825 Oak Grove Ave Ste C501', 'Menlo Park ', 'CA ', '94025', 'Delta Dental Premier', '4'),
#  (12, 'George Michaels', 'General Dentist', ' ', ' 0.9 mi', '825 Oak Grove Ave Ste C501', 'Menlo Park ', 'CA ', '94025', 'Delta Dental Premier', ''),
#  (13, 'Scott Hoffman', 'General Dentist', '4 out of 5 stars rating', ' 0.9 mi', '825 Oak Grove Ave #301', 'Menlo Park ', 'CA ', '94025', 'Delta Dental Premier', ''),
#  (14, 'ChauLong Nguyen', 'General Dentist', '4 out of 5 stars rating', ' 0.9 mi', '724 Oak Grove Ave Ste 120', 'Menlo Park ', 'CA ', '94025', 'Delta Dental Premier', '4'),
#  (15, 'Alok Arora', 'General Dentist', '4 out of 5 stars rating', ' 1 mi', '695 Oak Grove Ave Ste 300', 'Menlo Park ', 'CA ', '94025', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (16, 'Brian Lee', 'General Dentist', '4 out of 5 stars rating', ' 1 mi', '695 Oak Grove Ave Ste 300', 'Menlo Park ', 'CA ', '94025', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (17, 'Joseph Krauss', 'General Dentist', '4 out of 5 stars rating', ' 1.1 mi', '3351 El Camino Real Ste 235, ', 'Atherton ', 'CA ', '94027', 'Delta Dental Premier', '4'),
#  (18, 'Michael Brugos', 'General Dentist', '4 out of 5 stars rating', ' 1.1 mi', '3351 El Camino Real Ste 235, ', 'Atherton ', 'CA ', '94027', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (19, 'Nazila Doroodian', 'General Dentist', '4 out of 5 stars rating', ' 1.1 mi', '3301 El Camino Real Ste 280', 'Atherton ', 'CA ', '94027', 'Delta Dental Premier', ''),
#  (20, 'Samaneh Daftarian', 'General Dentist', '4 out of 5 stars rating', ' 1.1 mi', '625 Menlo Ave Ste 6', 'Menlo Park ', 'CA ', '94025', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (21, 'Derrick Sakata', 'General Dentist', ' ', ' 1.2 mi', '625 Menlo Ave Ste 6, ', 'Menlo Park ', 'CA ', '94025', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (22, 'Derrick Sakata', 'General Dentist', ' ', ' 1.2 mi', '625 Menlo Ave Ste 6', 'Menlo Park ', 'CA ', '94025', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (23, 'Daniel Schulze', 'General Dentist', '4 out of 5 stars rating', ' 1.2 mi', '625 Menlo Ave Ste 8', 'Menlo Park ', 'CA ', '94025', 'Delta Dental Premier', '4'),
#  (24, 'Gregory Roos', 'General Dentist', '4 out of 5 stars rating', ' 1.3 mi', '51 Renato Ct Ste C', 'Redwood City ', 'CA ', '94061', 'Delta Dental Premier', ''),
#  (25, 'Aja Hall', 'General Dentist', '4 out of 5 stars rating', ' 1.3 mi', '51 Renato Ct Ste C', 'Redwood City ', 'CA ', '94061', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (26, 'Richard Evangelista', 'General Dentist', '4 out of 5 stars rating', ' 1.3 mi', '51 Renato Ct Ste C', 'Redwood City ', 'CA ', '94061', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (27, 'Shruti Tandon', 'General Dentist', ' ', ' 1.3 mi', '51 Renato Ct Ste C', 'Redwood City ', 'CA ', '94061', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (28, 'Glenn Lew', 'General Dentist', '4 out of 5 stars rating', ' 1.4 mi', '35 Renato Ct Ste A', 'Redwood City ', 'CA ', '94061', 'Delta Dental Premier', ''),
#  (29, 'Norman Chang', 'General Dentist', '4 out of 5 stars rating', ' 1.4 mi', '35 Renato Ct Ste B', 'Redwood City ', 'CA ', '94061', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (30, 'Vincent Leung', 'General Dentist', '4 out of 5 stars rating', ' 1.4 mi', '35 Renato Ct Ste B', 'Redwood City ', 'CA ', '94061', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (31, 'Charles Carter', 'General Dentist', '4 out of 5 stars rating', ' 1.4 mi', '1391 Woodside Rd Ste 210', 'Redwood City ', 'CA ', '94061', 'Delta Dental Premier', '4'),
#  (32, 'Anupama Karehalliraju', 'General Dentist', '4 out of 5 stars rating', ' 1.4 mi', '1733 Woodside Rd Ste 110, ', 'Redwood City ', 'CA ', '94061', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (33, 'Donald Hermansen', 'General Dentist', '4 out of 5 stars rating', ' 1.4 mi', '1733 Woodside Rd Ste 110', 'Redwood City ', 'CA ', '94061', 'Delta Dental Premier', ''),
#  (34, 'Lok Choy', 'General Dentist', '4 out of 5 stars rating', ' 1.4 mi', '1733 Woodside Rd Ste 100', 'Redwood City ', 'CA ', '94061', 'Delta Dental Premier', ''),
#  (35, 'Rocio Alvizar', 'General Dentist', '4 out of 5 stars rating', ' 1.4 mi', '2825 El Camino Real', 'Redwood City ', 'CA ', '94061', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (36, 'Edwin Chicchon', 'General Dentist', '4 out of 5 stars rating', ' 1.4 mi', '959 Woodside Rd', 'Redwood City ', 'CA ', '94061', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (37, 'Shikha Puri', 'General Dentist', '4 out of 5 stars rating', ' 1.5 mi', '1690 Woodside Rd Ste 204', 'Redwood City ', 'CA ', '94061', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (38, 'Jeffrey Jones', 'General Dentist', ' ', ' 1.5 mi', '1690 Woodside Rd Ste 204', 'Redwood City ', 'CA ', '94061', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (39, 'Thuan-Vu Ho', 'General Dentist', '4 out of 5 stars rating', ' 1.5 mi', '1690 Woodside Rd Ste 118, ', 'Redwood City ', 'CA ', '94061', 'Delta Dental Premier', ''),
#  (40, 'Luis Meza', 'General Dentist', ' ', ' 1.5 mi', '3115 Middlefield Rd', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (41, 'Jay Cohen', 'General Dentist', '4 out of 5 stars rating', ' 1.5 mi', '902 Woodside Rd', 'Redwood City ', 'CA ', '94061', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (42, 'Dale Rubinchik', 'General Dentist', '4 out of 5 stars rating', ' 1.5 mi', '902 Woodside Rd', 'Redwood City ', 'CA ', '94061', 'Delta Dental PPO, Delta Dental Premier', '3'),
#  (43, 'Lei Luo', 'General Dentist', '4 out of 5 stars rating', ' 1.5 mi', '801 Woodside Rd Ste 3', 'Redwood City ', 'CA ', '94061', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (44, 'Scott Nabeta', 'General Dentist', '4 out of 5 stars rating', ' 1.6 mi', '425 Burgess Dr, ', 'Menlo Park ', 'CA ', '94025', 'Delta Dental Premier', ''),
#  (45, 'Gregory Ding', 'General Dentist', '4 out of 5 stars rating', ' 1.8 mi', '2531 El Camino Real', 'Redwood City ', 'CA ', '94061', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (46, 'Elizabeth Nguyen', 'General Dentist', '4 out of 5 stars rating', ' 1.8 mi', '2480 El Camino Real, ', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (47, 'Rafiah Khan', 'General Dentist', ' ', ' 1.8 mi', '2480 El Camino Real, ', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (48, 'Marivic Agoncillo-Laluces', 'General Dentist', '4 out of 5 stars rating', ' 1.8 mi', '2480 El Camino Real', 'Redwood City ', 'CA ', '94063', 'Delta Dental Premier', ''),
#  (49, 'Brittany Chou', 'General Dentist', ' ', ' 1.8 mi', '2480 El Camino Real, ', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (50, 'Rami Saah', 'General Dentist', ' ', ' 1.8 mi', '2710 Middlefield Rd', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (51, 'Tiffany Tsurudome', 'General Dentist', ' ', ' 1.8 mi', '2710 Middlefield Rd', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (52, 'Rami Saah', 'General Dentist', ' ', ' 1.8 mi', '2710 Middlefield Rd', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (53, 'Wendy Fung', 'General Dentist', '4 out of 5 stars rating', ' 1.8 mi', '2710 Middlefield Rd', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (54, 'Carol Boyd', 'General Dentist', ' ', ' 1.8 mi', '2710 Middlefield Rd', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (55, 'Osleydis Diaz', 'General Dentist', '4 out of 5 stars rating', ' 1.8 mi', '2710 Middlefield Rd', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (56, 'Michelle De Marta', 'General Dentist', '4 out of 5 stars rating', ' 1.9 mi', '321 Middlefield Rd Ste 100, ', 'Menlo Park ', 'CA ', '94025', 'Delta Dental Premier', '3'),
#  (57, 'Jeffery Starr', 'General Dentist', '4 out of 5 stars rating', ' 1.9 mi', '321 Middlefield Rd Ste 145', 'Menlo Park ', 'CA ', '94025', 'Delta Dental Premier', ''),
#  (58, 'Kate Matin', 'General Dentist', '4 out of 5 stars rating', ' 1.9 mi', '321 Middlefield Rd Ste 275', 'Menlo Park ', 'CA ', '94025', 'Delta Dental Premier', ''),
#  (59, 'William Tseng', 'General Dentist', '4 out of 5 stars rating', ' 2.1 mi', '251 High St Ste A', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', ''),
#  (60, 'Mudita Agrawal', 'General Dentist', '4 out of 5 stars rating', ' 2.1 mi', '3752 Florence St', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (61, 'Shervin Shariati', 'General Dentist', ' ', ' 2.1 mi', '3752 Florence St', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (62, 'Alvin Cenabre', 'General Dentist', '4 out of 5 stars rating', ' 2.3 mi', '2183 Roosevelt Ave', 'Redwood City ', 'CA ', '94061', 'Delta Dental Premier', ''),
#  (63, 'Victoria Goh', 'General Dentist', '4 out of 5 stars rating', ' 2.5 mi', '570 El Camino Real Ste 270', 'Redwood City ', 'CA ', '94063', 'Delta Dental Premier', ''),
#  (64, 'Jessica Lam', 'General Dentist', ' ', ' 2.5 mi', '570 El Camino Real Ste 270', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (65, 'Zahra Hakim-Faal', 'General Dentist', '4 out of 5 stars rating', ' 2.5 mi', '435 Middlefield Rd', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', '3'),
#  (66, 'Ali Heidari', 'General Dentist', '4 out of 5 stars rating', ' 2.5 mi', '517 Byron St, ', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', ''),
#  (67, 'Martha Vanzina', 'General Dentist', '4.5 out of 5 stars rating', ' 2.5 mi', '511 Byron St', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', ''),
#  (68, 'Steven Keller', 'General Dentist', ' ', ' 2.5 mi', '511 Byron St', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', ''),
#  (69, 'Shachi Bahl', 'General Dentist', '4 out of 5 stars rating', ' 2.5 mi', '511 Byron St', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', ''),
#  (70, 'Peter Kono', 'General Dentist', '4 out of 5 stars rating', ' 2.5 mi', '511 Byron St', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', ''),
#  (71, 'Robert Iverson', 'General Dentist', '4 out of 5 stars rating', ' 2.5 mi', '511 Byron St', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', ''),
#  (72, 'Rabindra Sahdev', 'General Dentist', '4 out of 5 stars rating', ' 2.5 mi', '882 Emerson St Ste C', 'Palo Alto ', 'CA ', '94301', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (73, 'Noel Alexas', 'General Dentist', '4.5 out of 5 stars rating', ' 2.5 mi', '2301 Jefferson Ave Ste 3', 'Washington ', 'PA ', '15301', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (74, 'Lora Costa', 'General Dentist', '4 out of 5 stars rating', ' 2.6 mi', '824 Bryant St', 'Palo Alto ', 'CA ', '94301', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', ''),
#  (75, 'Shahrzad Heidarian', 'General Dentist', '4.5 out of 5 stars rating', ' 2.6 mi', '826 Bryant St', 'Palo Alto ', 'CA ', '94301', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (76, 'Frank Altick', 'General Dentist', ' ', ' 2.6 mi', '824 Bryant St', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', ''),
#  (77, 'Alan Nguyen', 'General Dentist', '4 out of 5 stars rating', ' 2.6 mi', '1675 Broadway St Ste B, ', 'Redwood City ', 'CA ', '94063', 'Delta Dental Premier', ''),
#  (78, 'Denise Henderson', 'General Dentist', '4 out of 5 stars rating', ' 2.7 mi', '660 Middlefield Rd Ste A, ', 'Palo Alto ', 'CA ', '94301', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (79, 'Earl Whetstone', 'General Dentist', '4 out of 5 stars rating', ' 2.7 mi', '744 Middlefield Rd', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', '4'),
#  (80, 'Cristian Miranda', 'General Dentist', '4 out of 5 stars rating', ' 2.7 mi', '652 Homer Ave', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', '4'),
#  (81, 'Joan Chung', 'General Dentist', ' ', ' 2.7 mi', '900 Jefferson Ave', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (82, 'Payal Shah', 'General Dentist', '4 out of 5 stars rating', ' 2.7 mi', '900 Jefferson Ave', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (83, 'Beatriz Parra', 'General Dentist', '4 out of 5 stars rating', ' 2.8 mi', '3221 Jefferson Ave Ste 2A', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (84, 'Minal Patel', 'General Dentist', '4 out of 5 stars rating', ' 2.8 mi', '3221 Jefferson Ave Ste 2B', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', ''),
#  (85, 'Brian Yee', 'General Dentist', '4 out of 5 stars rating', ' 2.8 mi', '1059 El Camino Real', 'Redwood City ', 'CA ', '94063', 'Delta Dental Premier', ''),
#  (86, 'Anandhi Djegaradjane', 'General Dentist', '4 out of 5 stars rating', ' 2.8 mi', '910 Willow Rd', 'Menlo Park ', 'CA ', '94025', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (87, 'Eric Kwon', 'General Dentist', '4 out of 5 stars rating', ' 2.8 mi', '850 Middlefield Rd Ste 2', 'Palo Alto ', 'CA ', '94301', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (88, 'Roshan Emam', 'General Dentist', '4 out of 5 stars rating', ' 2.8 mi', '850 Middlefield Rd Ste 8, ', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', '4'),
#  (89, 'Delores Eberhart', 'General Dentist', '4 out of 5 stars rating', ' 2.8 mi', '880 Middlefield Rd', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', '4'),
#  (90, 'Mary Qian', 'General Dentist', '4 out of 5 stars rating', ' 2.8 mi', '888 Middlefield Rd', 'Palo Alto ', 'CA ', '94301', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (91, 'Nazia Malik', 'General Dentist', '4 out of 5 stars rating', ' 2.8 mi', '853 Middlefield Rd Ste 1', 'Palo Alto ', 'CA ', '94301', 'Delta Dental PPO, Delta Dental Premier', '2'),
#  (92, 'Madhurima Ganguly', 'General Dentist', '4 out of 5 stars rating', ' 2.8 mi', '853 Middlefield Rd Ste 1', 'Palo Alto ', 'CA ', '94301', 'Delta Dental PPO, Delta Dental Premier', '2'),
#  (93, 'Ayesha Qazi', 'General Dentist', '4 out of 5 stars rating', ' 2.8 mi', '853 Middlefield Rd Ste 1', 'Palo Alto ', 'CA ', '94301', 'Delta Dental PPO, Delta Dental Premier', '2'),
#  (94, 'Ala Din', 'General Dentist', '4 out of 5 stars rating', ' 2.8 mi', '905 Middlefield Rd Ste B, ', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', ''),
#  (95, 'Eugene Roytman', 'General Dentist', '4 out of 5 stars rating', ' 2.9 mi', '1105 Veterans Blvd Ste D', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', '3'),
#  (96, 'Yuliya Morozova', 'General Dentist', '4 out of 5 stars rating', ' 2.9 mi', '1105 Veterans Blvd Ste D', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (97, 'Meera Sravan Kumar', 'General Dentist', ' ', ' 3 mi', '975 Veterans Blvd', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', '2'),
#  (98, 'Christine Ho', 'General Dentist', '4 out of 5 stars rating', ' 3 mi', '975 Veterans Blvd', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', '1'),
#  (99, 'Maung Zaw', 'General Dentist', ' ', ' 3 mi', '975 Veterans Blvd', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', '1'),
#  (100, 'Erika Peterson', 'General Dentist', '4.5 out of 5 stars rating', ' 3 mi', '369 Main St Ste 250, ', 'Redwood City ', 'CA ', '94063', 'Delta Dental Premier', ''),
#  (101, 'Jean Elizab Barthman', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '801 Brewster Ave Ste 255', 'Redwood City ', 'CA ', '94063', 'Delta Dental Premier', ''),
#  (102, 'Siva Cherukuri', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '193 Arch St Ste B-C', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', '1'),
#  (103, 'Robert Wolf', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '193 Arch St', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (104, 'Alfonso Gonzalez', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '2943 Broadway Ste 4, ', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', ''),
#  (105, 'Ghina Morad', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '2920 Broadway', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', '4'),
#  (106, 'Clark Fong', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '155 Birch St Ste 5', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (107, 'Brian Fong', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '3023 Broadway', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', ''),
#  (108, 'Michelle Kim', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '154 Arch St', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (109, 'James Kim', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '154 Arch St', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (110, 'Eugene Espiritu', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '705 Veterans Blvd Ste 1', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', '3'),
#  (111, 'Mayra Escobar', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '155 Birch St Ste 3', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (112, 'Michael Sala', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '150 Arch St Ste E', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', ''),
#  (113, 'Sanford Daniel', 'General Dentist', '4.5 out of 5 stars rating', ' 3.1 mi', '150 Arch St', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', '4'),
#  (114, 'Michael Sala', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '150 Arch St', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', ''),
#  (115, 'Michelle Lacues', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '150 Arch St Ste B', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', ''),
#  (116, 'Pratibha Vegulla', 'General Dentist', '4 out of 5 stars rating', ' 3.1 mi', '150 Arch St Ste A', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (117, 'David Mckenna', 'General Dentist', '4 out of 5 stars rating', ' 3.2 mi', '1691 El Camino Real Ste 300', 'Palo Alto ', 'CA ', '94306', 'Delta Dental Premier', ''),
#  (118, 'Daniel Mendoza', 'General Dentist', '4 out of 5 stars rating', ' 3.2 mi', '133 Arch St Ste 1', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (119, 'Gayatri Sakhrani', 'General Dentist', '4 out of 5 stars rating', ' 3.2 mi', '114 Birch St Ste D', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (120, 'Frederic Holloszy', 'General Dentist', ' ', ' 3.2 mi', '114 Birch St Ste D', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', ''),
#  (121, 'Albert Sadakian', 'General Dentist', '4 out of 5 stars rating', ' 3.2 mi', '114 Birch St Ste B', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', '3'),
#  (122, 'Pinalben Viraparia', 'General Dentist', '4 out of 5 stars rating', ' 3.2 mi', '114 Birch St Ste D', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (123, 'Elly Triplett', 'General Dentist', '4 out of 5 stars rating', ' 3.2 mi', '114 Birch St Ste A', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', '5'),
#  (124, 'Sergey Oumnov', 'General Dentist', '4 out of 5 stars rating', ' 3.2 mi', '114 Birch St Ste C', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', ''),
#  (125, 'Shabnam Mahzoon', 'General Dentist', '4 out of 5 stars rating', ' 3.2 mi', '647 Veterans Blvd', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (126, 'Ramiz Petros', 'General Dentist', '4 out of 5 stars rating', ' 3.2 mi', '1122 Hopkins Ave, ', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (127, 'Seyedbabak Mostaan', 'General Dentist', '4 out of 5 stars rating', ' 3.2 mi', '1805 El Camino Real Ste 202', 'Palo Alto ', 'CA ', '94306', 'Delta Dental Premier', ''),
#  (128, 'Nelson Tordilla', 'General Dentist', ' ', ' 3.3 mi', '81 Birch St', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (129, 'Jeff Eaton', 'General Dentist', '4 out of 5 stars rating', ' 3.3 mi', '81 Birch St', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (130, 'Anne Spiegel', 'General Dentist', '4 out of 5 stars rating', ' 3.3 mi', '81 Birch St', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', ''),
#  (131, 'Sheila Kodani', 'General Dentist', '4 out of 5 stars rating', ' 3.3 mi', '93 Arch St, ', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', '5'),
#  (132, 'Aneet Randhawa', 'General Dentist', '4 out of 5 stars rating', ' 3.3 mi', '570 El Camino Real Ste 130', 'Redwood City ', 'CA ', '94063', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', ''),
#  (133, 'Sylvia Tso', 'General Dentist', '4 out of 5 stars rating', ' 3.3 mi', '52 Arch St  Ste 4', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', '5'),
#  (134, 'Nogol Rashidi', 'General Dentist', '4 out of 5 stars rating', ' 3.3 mi', '40 Birch St Ste A', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', ''),
#  (135, 'Goly Barar', 'General Dentist', ' ', ' 3.3 mi', '40 Birch St Ste A', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', ''),
#  (136, 'William Meza', 'General Dentist', '4 out of 5 stars rating', ' 3.3 mi', '29 Birch St Ste 3', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (137, 'Javier Lopez', 'General Dentist', ' ', ' 3.3 mi', '20 Birch St', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (138, 'Marina Rozhavsky', 'General Dentist', '4 out of 5 stars rating', ' 3.3 mi', '20 Birch St', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (139, 'Ihab Hanna', 'General Dentist', '4 out of 5 stars rating', ' 3.3 mi', '20 Birch St', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', '4'),
#  (140, 'Robert Plant', 'General Dentist', '4 out of 5 stars rating', ' 3.3 mi', '25 Arch St Ste A', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', ''),
#  (141, 'Stephen Lindblom', 'General Dentist', '4 out of 5 stars rating', ' 3.3 mi', '25 Arch St, ', 'Redwood City ', 'CA ', '94062', 'Delta Dental Premier', '5'),
#  (142, 'Paramita Roy', 'General Dentist', '4 out of 5 stars rating', ' 3.4 mi', '2950 Whipple Ave Ste 9, ', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (143, 'Munazzah Hussain', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '2290 Birch St Ste A', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (144, 'Alex Yen', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '2290 Birch St Ste A', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (145, 'Safa Khaleel', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '2290 Birch St Ste C, ', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (146, 'Adrienne Van', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '2290 Birch St Ste C', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (147, 'Munazzah Hussain', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '2290 Birch St Ste A', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (148, 'Dania Armas', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '222 El Camino Real', 'Redwood City ', 'CA ', '94062', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (149, 'Kris Hamamoto', 'General Dentist', '4.5 out of 5 stars rating', ' 3.6 mi', '409 Cambridge Ave, ', 'Palo Alto ', 'CA ', '94306', 'Delta Dental Premier', '4'),
#  (150, 'Elliot Singer', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '407 Cambridge Ave, ', 'Palo Alto ', 'CA ', '94306', 'Delta Dental Premier', '5'),
#  (151, 'Marc Tully', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '407 Cambridge Ave, ', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (152, 'Richard Marlinski', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '409 Cambridge Ave', 'Palo Alto ', 'CA ', '94306', 'Delta Dental Premier', '5'),
#  (153, 'Alex Yen', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '409 Cambridge Ave', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (154, 'Scott Pyon', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '405 Cambridge Ave', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (155, 'Hui-An Ho', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '2345 Yale St Ste 2B, ', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (156, 'Constance Mazzetti', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '2235 Alma St', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', ''),
#  (157, 'Laura Mayer', 'General Dentist', ' ', ' 3.6 mi', '2235 Alma St', 'Palo Alto ', 'CA ', '94301', 'Delta Dental Premier', ''),
#  (158, 'Ken Kato', 'General Dentist', ' ', ' 3.6 mi', '2421 Park Blvd Ste A204', 'Palo Alto ', 'CA ', '94306', 'Delta Dental Premier', ''),
#  (159, 'Elaine Cabreza', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '2421 Park Blvd Ste A204', 'Palo Alto ', 'CA ', '94306', 'Delta Dental Premier', ''),
#  (160, 'Ramtin Rastakhiz', 'General Dentist', '4 out of 5 stars rating', ' 3.6 mi', '2235 Alma St', 'Palo Alto ', 'CA ', '94301', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (161, 'Stanley Lin', 'General Dentist', '4 out of 5 stars rating', ' 3.7 mi', '117 California Ave Ste D200', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (162, 'John Wayland', 'General Dentist', ' ', ' 3.7 mi', '2421 Park Blvd Ste A200, ', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (163, 'Galina Nasakin', 'General Dentist', '4 out of 5 stars rating', ' 3.7 mi', '2421 Park Blvd Ste A200, ', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (164, 'Mikhail Nasakin', 'General Dentist', '4 out of 5 stars rating', ' 3.7 mi', '2421 Park Blvd Ste A200, ', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (165, 'Radhika Alampalli', 'General Dentist', '4 out of 5 stars rating', ' 3.8 mi', '1765 E Bayshore Rd Unit H', 'East Palo Alto ', 'CA ', '94303', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (166, 'Shivani Gupta', 'General Dentist', '4 out of 5 stars rating', ' 3.8 mi', '1201 Saint Francis Way', 'San Carlos ', 'CA ', '94070', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (167, 'Kenneth Turner', 'General Dentist', ' ', ' 3.8 mi', '1201 Saint Francis Way', 'San Carlos ', 'CA ', '94070', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (168, 'Jaime Lau', 'General Dentist', '4 out of 5 stars rating', ' 3.9 mi', '1552 Laurel St', 'San Carlos ', 'CA ', '94070', 'Delta Dental Premier', ''),
#  (169, 'Zachary Held', 'General Dentist', '4 out of 5 stars rating', ' 3.9 mi', '1552 Laurel St', 'San Carlos ', 'CA ', '94070', 'Delta Dental Premier', ''),
#  (170, 'Frank Hsu', 'General Dentist', '4 out of 5 stars rating', ' 3.9 mi', '1553 Laurel St Ste A', 'San Carlos ', 'CA ', '94070', 'Delta Dental Premier', ''),
#  (171, 'Kathleen Yau', 'General Dentist', ' ', ' 4 mi', '1807 Bay Rd, ', 'East Palo Alto ', 'CA ', '94303', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (172, 'Helen Trinh', 'General Dentist', ' ', ' 4 mi', '1807 Bay Rd, ', 'East Palo Alto ', 'CA ', '94303', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (173, 'Natalie Okuhara', 'General Dentist', '4 out of 5 stars rating', ' 4 mi', '1807 Bay Rd, ', 'East Palo Alto ', 'CA ', '94303', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', ''),
#  (174, 'Sailaja Nalamati', 'General Dentist', ' ', ' 4 mi', '1807 Bay Rd, ', 'East Palo Alto ', 'CA ', '94303', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (175, 'Alison Adachi', 'General Dentist', ' ', ' 4 mi', '1807 Bay Rd, ', 'East Palo Alto ', 'CA ', '94303', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (176, 'Zahra Ezzy', 'General Dentist', ' ', ' 4 mi', '1807 Bay Rd, ', 'East Palo Alto ', 'CA ', '94303', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (177, 'Jonathan Hurng', 'General Dentist', ' ', ' 4 mi', '1807 Bay Rd, ', 'East Palo Alto ', 'CA ', '94303', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (178, 'Jean Wu', 'General Dentist', '4 out of 5 stars rating', ' 4.2 mi', '1267 Laurel St', 'San Carlos ', 'CA ', '94070', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (179, 'Amrit Singh', 'General Dentist', '4 out of 5 stars rating', ' 4.2 mi', '2700 Middlefield Rd, ', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (180, 'Kimberly Kato', 'General Dentist', '4.5 out of 5 stars rating', ' 4.2 mi', '689 Colorado Ave', 'Palo Alto ', 'CA ', '94306', 'Delta Dental Premier', ''),
#  (181, 'Lance Nakamitsu', 'General Dentist', '4 out of 5 stars rating', ' 4.2 mi', '689 Colorado Ave', 'Palo Alto ', 'CA ', '94306', 'Delta Dental Premier', ''),
#  (182, 'Steven Kato', 'General Dentist', '4 out of 5 stars rating', ' 4.2 mi', '689 Colorado Ave', 'Palo Alto ', 'CA ', '94306', 'Delta Dental Premier', ''),
#  (183, 'Kimberly Kato', 'General Dentist', '4.5 out of 5 stars rating', ' 4.2 mi', '689 Colorado Ave', 'Palo Alto ', 'CA ', '94306', 'Delta Dental Premier', ''),
#  (184, 'Jenela Chow', 'General Dentist', '4 out of 5 stars rating', ' 4.3 mi', '1125 Laurel St', 'San Carlos ', 'CA ', '94070', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (185, 'Mathew Chow', 'General Dentist', '4 out of 5 stars rating', ' 4.3 mi', '1125 Laurel St', 'San Carlos ', 'CA ', '94070', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (186, 'Zahra Akhondi', 'General Dentist', '4.5 out of 5 stars rating', ' 4.4 mi', '1186 Brittan Ave, ', 'San Carlos ', 'CA ', '94070', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (187, 'Durkman Hong', 'General Dentist', '4 out of 5 stars rating', ' 4.5 mi', '990 Laurel St Ste B', 'San Carlos ', 'CA ', '94070', 'Delta Dental Premier', ''),
#  (188, 'Terence Clancy', 'General Dentist', '4.5 out of 5 stars rating', ' 4.5 mi', '990 Laurel St Ste D', 'San Carlos ', 'CA ', '94070', 'Delta Dental Premier', ''),
#  (189, 'Jerold Alvarado', 'General Dentist', '4 out of 5 stars rating', ' 4.5 mi', '990 Laurel St Ste C', 'San Carlos ', 'CA ', '94070', 'Delta Dental Premier', ''),
#  (190, 'Douglas Arakawa', 'General Dentist', '4 out of 5 stars rating', ' 4.7 mi', '3200 Middlefield Rd Ste A', 'Palo Alto ', 'CA ', '94306', 'Delta Dental Premier', '4'),
#  (191, 'Brandon Phuong', 'General Dentist', '4 out of 5 stars rating', ' 4.7 mi', '796 El Camino Real Ste A', 'San Carlos ', 'CA ', '94070', 'Delta Dental PPO, Delta Dental Premier', '4'),
#  (192, 'Donald Curia', 'General Dentist', '4 out of 5 stars rating', ' 4.8 mi', '731 Walnut St, ', 'San Carlos ', 'CA ', '94070', 'Delta Dental Premier', '4'),
#  (193, 'Nazanin Morshedi', 'General Dentist', '4 out of 5 stars rating', ' 4.9 mi', '3505 Alma St', 'Palo Alto ', 'CA ', '94306', 'Delta Dental Premier', '4'),
#  (194, 'Sepideh Agah', 'General Dentist', '4 out of 5 stars rating', ' 4.9 mi', '3517 Alma St', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', ''),
#  (195, 'Brad Hart', 'General Dentist', '4 out of 5 stars rating', ' 4.9 mi', '1785 San Carlos Ave Ste 1', 'San Carlos ', 'CA ', '94070', 'Delta Dental Premier', ''),
#  (196, 'Hui-An Ho', 'General Dentist', '4 out of 5 stars rating', ' 4.9 mi', '2345 Yale St Fl 2A, ', 'Palo Alto ', 'CA ', '94306', 'Delta Dental PPO, Delta Dental Premier', '5'),
#  (197, 'Valerie Gilman', 'General Dentist', '4 out of 5 stars rating', ' 4.9 mi', '1785 San Carlos Ave Ste 5', 'San Carlos ', 'CA ', '94070', 'Delta Dental Premier', ''),
#  (198, 'Anthony Marcos', 'General Dentist', '4 out of 5 stars rating', ' 5 mi', '1375 San Carlos Ave Ste A, ', 'San Carlos ', 'CA ', '94070', 'Delta Dental Premier', ''),
#  (199, 'Carliza Marcos', 'General Dentist', '4 out of 5 stars rating', ' 5 mi', '1375 San Carlos Ave Ste A, ', 'San Carlos ', 'CA ', '94070', 'Delta Dental Premier', '4'),
#  (200, 'Dipty Parikh', 'General Dentist', '4 out of 5 stars rating', ' 5 mi', '1512 San Carlos Ave', 'San Carlos ', 'CA ', '94070', 'Delta Dental PPO, Delta Dental Premier', '4')]

# %% [markdown]
# # Exploratory Queries:

# %% [markdown]
# Query 1
# Purpose: See what the demohraphic percentages are by zip code

# %%
# %%sql
# WITH demographic_CTE AS (
#     SELECT
#         zd.population AS pop,
#         zr.zip_code,
#         zr.white,
#         zr.black,
#         zr.american_indian,
#         zr.asian,
#         zr.native_hawaiian,
#         zr.other_race,
#         zr.two_or_more
#     FROM zip_race zr
#     JOIN zip_demographics zd
#         ON zr.zip_code = zd.zip_code
# )
# SELECT
#     zip_code,
#     FORMAT((white / pop)*100, 'P') AS white_population,
#     FORMAT((black / pop)*100, 'P') AS black_population,
#     FORMAT((american_indian / pop)*100, 'P') AS american_indian_population,
#     FORMAT((asian / pop)*100, 'P') AS asian_population,
#     FORMAT((native_hawaiian / pop)*100, 'P') AS hawaiian_population,
#     FORMAT((other_race / pop)*100, 'P') AS other_race_population,
#     FORMAT((two_or_more / pop)*100, 'P') AS two_or_more_population,
# CASE
#     WHEN zip_code LIKE '94%' THEN 'High_Income_Zip'
#     WHEN zip_code LIKE '93%' THEN 'Low_Income_Zip'
# END AS Zip_Category
# FROM demographic_CTE
# ORDER BY white_population ASC;
# Out:
#  * mysql://admin:***@dnaka-sql-final.c8e00slqxvtw.us-east-1.rds.amazonaws.com/sql_final_project
# 21 rows affected.
# [('93706', '36', '18', '2', '9', '0', '30', '4', 'Low_Income_Zip'),
#  ('93701', '36', '6', '3', '10', '0', '40', '5', 'Low_Income_Zip'),
#  ('94303', '40', '11', '0', '15', '5', '24', '5', 'High_Income_Zip'),
#  ('93703', '40', '7', '2', '14', '0', '32', '4', 'Low_Income_Zip'),
#  ('93727', '46', '7', '1', '21', '0', '20', '5', 'Low_Income_Zip'),
#  ('94063', '46', '3', '1', '5', '2', '38', '6', 'High_Income_Zip'),
#  ('93726', '48', '9', '2', '13', '0', '24', '5', 'Low_Income_Zip'),
#  ('93705', '51', '10', '2', '6', '0', '26', '5', 'Low_Income_Zip'),
#  ('93728', '54', '6', '3', '4', '0', '27', '6', 'Low_Income_Zip'),
#  ('94306', '61', '2', '0', '29', '0', '3', '4', 'High_Income_Zip'),
#  ('93710', '62', '8', '1', '9', '0', '13', '5', 'Low_Income_Zip'),
#  ('93721', '62', '12', '2', '4', '0', '17', '3', 'Low_Income_Zip'),
#  ('93704', '64', '5', '1', '5', '0', '19', '5', 'Low_Income_Zip'),
#  ('94061', '65', '2', '1', '6', '1', '20', '5', 'High_Income_Zip'),
#  ('93612', '67', '4', '2', '8', '0', '14', '5', 'Low_Income_Zip'),
#  ('94025', '71', '4', '0', '10', '1', '9', '5', 'High_Income_Zip'),
#  ('93711', '74', '5', '1', '7', '0', '9', '4', 'Low_Income_Zip'),
#  ('94301', '76', '2', '0', '16', '0', '2', '4', 'High_Income_Zip'),
#  ('94070', '79', '1', '0', '11', '0', '3', '5', 'High_Income_Zip'),
#  ('94027', '80', '1', '0', '13', '1', '1', '3', 'High_Income_Zip'),
#  ('94062', '82', '1', '0', '7', '0', '5', '4', 'High_Income_Zip')]

# %% [markdown]
# Discovery: I discovered that the higher income zip codes have a predominately white population when compared to lower income zip codes.

# %% [markdown]
# ***

# %% [markdown]
# Query 2
# Purpose: Find the number of different zip codes in my data set

# %%
# %%sql
# SELECT COUNT(DISTINCT zip_code)
# FROM lowIncome_zip liz
# UNION
# SELECT COUNT(DISTINCT zip_code)
# FROM wealthy_zip wz
# Out:
#  * mysql://admin:***@dnaka-sql-final.c8e00slqxvtw.us-east-1.rds.amazonaws.com/sql_final_project
# 2 rows affected.
# [(12,), (9,)]

# %% [markdown]
# Discovery: I found that there are 21 unique zip codes

# %% [markdown]
# ***

# %% [markdown]
# Query 3
# Purpose: Find what cells in the yelp and dentalqual rating columns are empty so that I can replace those cells (I did my Primary question and secondary questions prior to my exploring queries so I have already replaced those cells)

# %%
# %%sql
# SELECT
#     dq_rating,
#     yelp_rating
# FROM lowIncome_zip
# WHERE dq_rating = ' '
# AND yelp_rating = ''
# UNION
# SELECT
#     dq_rating,
#     yelp_rating
# FROM wealthy_zip
# WHERE dq_rating = ' '
# AND yelp_rating = ''
# Out:
#  * mysql://admin:***@dnaka-sql-final.c8e00slqxvtw.us-east-1.rds.amazonaws.com/sql_final_project
# 0 rows affected.
# []

# %% [markdown]
# Discovery: I found what cells that I need to insert data into (I assume that if there is no rating, the rating must be lower than 3. Therefore, I inserted 2 for all of the missing ratings.

# %% [markdown]
# ***

# %% [markdown]
# Query 4
# Purpose: Find ut how many dentists are in each zip code category

# %%
# %%sql
# WITH dent_cte AS (
#     SELECT
#         liz.dq_rating,
#         liz.yelp_rating,
#         liz.zip_code,
#         CASE
#             WHEN liz.zip_code LIKE '94%' THEN 'High_Income_Zip'
#             WHEN liz.zip_code LIKE '93%' THEN 'Low_Income_Zip'
#         END AS Zip_Category
#     FROM lowIncome_zip liz
#     UNION ALL
#     SELECT
#         wz.dq_rating,
#         wz.yelp_rating,
#         wz.zip_code,
#         CASE
#             WHEN wz.zip_code LIKE '94%' THEN 'High_Income_Zip'
#             WHEN wz.zip_code LIKE '93%' THEN 'Low_Income_Zip'
#         END AS Zip_Category
#     FROM wealthy_zip wz
# )
# SELECT
#     COUNT(CASE WHEN Zip_Category = 'High_Income_Zip' THEN 1 END) AS NumDentinHighZip,
#     COUNT(CASE WHEN Zip_Category = 'Low_Income_Zip' THEN 1 END) AS NumDentinLowZip
# FROM dent_cte;
# Out:
#  * mysql://admin:***@dnaka-sql-final.c8e00slqxvtw.us-east-1.rds.amazonaws.com/sql_final_project
# 1 rows affected.
# [(199, 181)]

# %% [markdown]
# Discovery: I found out that the zip codes from the higher income zip codes have 00000 number of dentists and the zip codes from the lower income have 0000 number of dentists

# %% [markdown]
# ***

# %% [markdown]
# Query 5
# Purpose: Find out the scope of my data set (scope of the median house hold income)

# %%
# %%sql
# SELECT
#     MIN(median_household_income) AS MinMedianIncome,
#     MAX(median_household_income) AS MaxMedianIncome
# FROM zip_demographics
# Out:
#  * mysql://admin:***@dnaka-sql-final.c8e00slqxvtw.us-east-1.rds.amazonaws.com/sql_final_project
# 1 rows affected.
# [(16597, 220583)]

# %% [markdown]
# Discovery: I found that there is a large difference between the min and max median household income in my data set which was not necessarily a surprise.

# %% [markdown]
# # Primary Question and Two Related Questions:

# %% [markdown]
# Primary Question: Does your zip code wealth affect the quality of dentists available in your area?
#
# Business Justification: This would be helpful because if there is a drastic difference of availability in the quality of dentists based off of your zip code's wealth, then an insurance company can see if lowering costs for dentists or increasing pay in that area as an incentive would increase the number of quality dentists in the lower income zip code.
#
# Features Used: CTE, JOIN (UNION), CASE, Window Function, GROUP BY
# (First query is to update my data tables based off my assumption)

# %%
# %%sql
# #ASSUMPTION: When there is no dq_rating, the rating must be 2 or lower, and if there is no yelp rating is must be 2 or lower
# UPDATE lowIncome_zip
# SET
#     dq_rating = '2 out of 5 starts rating',
#     yelp_rating = '2'
# WHERE dq_rating = ' '
# AND yelp_rating = '';
#
# UPDATE wealthy_zip
# SET
#     dq_rating = '2 out of 5 starts rating',
#     yelp_rating = '2'
# WHERE dq_rating = ' '
# AND yelp_rating = '';
# Out:
#  * mysql://admin:***@dnaka-sql-final.c8e00slqxvtw.us-east-1.rds.amazonaws.com/sql_final_project
# 0 rows affected.
# 24 rows affected.
# []

# %%
# %%sql
# WITH rating_CTE AS (
#     SELECT
#         liz.dq_rating,
#         liz.yelp_rating,
#         liz.zip_code,
#         COUNT(CASE WHEN yelp_rating = '1' THEN 1 END) AS yelp_1,
#         COUNT(CASE WHEN yelp_rating = '2' THEN 1 END) AS yelp_2,
#         COUNT(CASE WHEN yelp_rating = '3' THEN 1 END) AS yelp_3,
#         COUNT(CASE WHEN yelp_rating = '4' THEN 1 END) AS yelp_4,
#         COUNT(CASE WHEN yelp_rating = '5' THEN 1 END) AS yelp_5,
#         COUNT(CASE WHEN dq_rating LIKE '1%' THEN 1 END) AS dq_1,
#         COUNT(CASE WHEN dq_rating LIKE '2%' THEN 1 END) AS dq_2,
#         COUNT(CASE WHEN dq_rating LIKE '3%' THEN 1 END) AS dq_3,
#         COUNT(CASE WHEN dq_rating LIKE '4%' THEN 1 END) AS dq_4,
#         COUNT(CASE WHEN dq_rating LIKE '5%' THEN 1 END) AS dq_5,
#         CASE
#             WHEN liz.zip_code LIKE '94%' THEN 'High_Income_Zip'
#             WHEN liz.zip_code LIKE '93%' THEN 'Low_Income_Zip'
#         END AS Zip_Category
#     FROM lowIncome_zip liz
#     GROUP BY Zip_Category
#     UNION ALL
#     SELECT
#         wz.dq_rating,
#         wz.yelp_rating,
#         wz.zip_code,
#         COUNT(CASE WHEN yelp_rating = '1' THEN 1 END) AS yelp_1,
#         COUNT(CASE WHEN yelp_rating = '2' THEN 1 END) AS yelp_2,
#         COUNT(CASE WHEN yelp_rating = '3' THEN 1 END) AS yelp_3,
#         COUNT(CASE WHEN yelp_rating = '4' THEN 1 END) AS yelp_4,
#         COUNT(CASE WHEN yelp_rating = '5' THEN 1 END) AS yelp_5,
#         COUNT(CASE WHEN dq_rating LIKE '1%' THEN 1 END) AS dq_1,
#         COUNT(CASE WHEN dq_rating LIKE '2%' THEN 1 END) AS dq_2,
#         COUNT(CASE WHEN dq_rating LIKE '3%' THEN 1 END) AS dq_3,
#         COUNT(CASE WHEN dq_rating LIKE '4%' THEN 1 END) AS dq_4,
#         COUNT(CASE WHEN dq_rating LIKE '5%' THEN 1 END) AS dq_5,
#         CASE
#             WHEN wz.zip_code LIKE '94%' THEN 'High_Income_Zip'
#             WHEN wz.zip_code LIKE '93%' THEN 'Low_Income_Zip'
#         END AS Zip_Category
#     FROM wealthy_zip wz
#     GROUP BY Zip_Category
# )
# SELECT
#     Zip_Category,
#     yelp_1,
#     yelp_2,
#     yelp_3,
#     yelp_4,
#     yelp_5,
#     dq_1,
#     dq_2,
#     dq_3,
#     dq_4,
#     dq_5
# FROM rating_CTE rcte;
# Out:
#  * mysql://admin:***@dnaka-sql-final.c8e00slqxvtw.us-east-1.rds.amazonaws.com/sql_final_project
# 2 rows affected.
# [('Low_Income_Zip', 6, 115, 16, 15, 29, 0, 57, 1, 123, 0),
#  ('High_Income_Zip', 3, 121, 6, 43, 26, 0, 35, 0, 164, 0)]

# %% [markdown]
# Recommendation: I reccomend that there is no need to provide an incentive to have higher rated dentists in the lower income zip code or higher income zip code as the ratings are fairly similar across the board.

# %% [markdown]
# ***

# %% [markdown]
# Related Question 1: What is the ratio of dentist to population?
#
# Business Justification: This would be beneficial for an insurance company such as Delta Dental because it can see if there is a greater demand for dentists in a certain zip code. Then, it can provide that data to dentists who are looking to change location who may have concerns about business. Additionally, if needed, Delta Dental could provide incentives for more dentists to start practicing close to a certain zip code to increase the overall number of dentists.
#
# Features Used: CTE, JOIN, CASE, Subquery, Window Function, GROUP BY

# %%
# %%sql
# WITH zDem_lowIncome_CTE AS (
#         SELECT
#             liz_id AS total_dent,
#             liz.zip_code,
#             population
#         FROM zip_demographics zd
#         JOIN lowIncome_zip liz
#             ON zd.zip_code = liz.zip_code
#         WHERE zd.zip_code LIKE '93%'
#         GROUP BY liz.zip_code
#     ),
#     zDem_highIncome_CTE AS (
#         SELECT
#             wz_id AS total_dent,
#             wz.zip_code,
#             population
#         FROM zip_demographics zd
#         JOIN wealthy_zip wz
#             ON zd.zip_code = wz.zip_code
#         WHERE zd.zip_code LIKE '94%'
#         GROUP BY wz.zip_code
#     )
# SELECT
#     zip_code,
#     ROUND((population / total_dent)) AS Number_Pple_Per_Dentist_Zip_Pop,
#     (
#      SELECT
#         ROUND(SUM(population) / SUM(total_dent))
#      FROM zDem_lowIncome_CTE
#     ) AS Number_Pple_Per_Dentist_Whole_Pop,
# CASE
#     WHEN zip_code LIKE '94%' THEN 'High_Income_Zip'
#     WHEN zip_code LIKE '93%' THEN 'Low_Income_Zip'
# END AS Zip_Category
# FROM zDem_lowIncome_CTE
# UNION ALL
# SELECT
#     zip_code,
#     ROUND((population / total_dent)) AS  Number_Pple_Per_Dentist,
#     (
#      SELECT
#         ROUND(SUM(population) / SUM(total_dent))
#      FROM zDem_highIncome_CTE
#     ) AS Number_Pple_Per_Dentist_Whole_Pop,
# CASE
#     WHEN zip_code LIKE '94%' THEN 'High_Income_Zip'
#     WHEN zip_code LIKE '93%' THEN 'Low_Income_Zip'
# END AS Zip_Category
# FROM zDem_highIncome_CTE;
# Out:
#  * mysql://admin:***@dnaka-sql-final.c8e00slqxvtw.us-east-1.rds.amazonaws.com/sql_final_project
# 21 rows affected.
# [('93701', Decimal('12529'), Decimal('632'), 'Low_Income_Zip'),
#  ('93721', Decimal('994'), Decimal('632'), 'Low_Income_Zip'),
#  ('93703', Decimal('1328'), Decimal('632'), 'Low_Income_Zip'),
#  ('93728', Decimal('630'), Decimal('632'), 'Low_Income_Zip'),
#  ('93706', Decimal('1174'), Decimal('632'), 'Low_Income_Zip'),
#  ('93726', Decimal('1018'), Decimal('632'), 'Low_Income_Zip'),
#  ('93727', Decimal('1355'), Decimal('632'), 'Low_Income_Zip'),
#  ('93705', Decimal('680'), Decimal('632'), 'Low_Income_Zip'),
#  ('93710', Decimal('339'), Decimal('632'), 'Low_Income_Zip'),
#  ('93704', Decimal('302'), Decimal('632'), 'Low_Income_Zip'),
#  ('93612', Decimal('368'), Decimal('632'), 'Low_Income_Zip'),
#  ('93711', Decimal('375'), Decimal('632'), 'Low_Income_Zip'),
#  ('94025', Decimal('40526'), Decimal('385'), 'High_Income_Zip'),
#  ('94027', Decimal('417'), Decimal('385'), 'High_Income_Zip'),
#  ('94061', Decimal('1510'), Decimal('385'), 'High_Income_Zip'),
#  ('94063', Decimal('774'), Decimal('385'), 'High_Income_Zip'),
#  ('94301', Decimal('288'), Decimal('385'), 'High_Income_Zip'),
#  ('94062', Decimal('312'), Decimal('385'), 'High_Income_Zip'),
#  ('94306', Decimal('226'), Decimal('385'), 'High_Income_Zip'),
#  ('94303', Decimal('276'), Decimal('385'), 'High_Income_Zip'),
#  ('94070', Decimal('176'), Decimal('385'), 'High_Income_Zip')]

# %% [markdown]
# Recommendation: It is apparent that there are significantly less dentists for the population in the lower income zip code. Additionally, there are significantly more individuals than dentists in every zip code. Therefore, I would recommend Delta Dental either expanding their network to include more dentists in these zip codes, or reach out to dentists to increase their numbers in all of these zip codes.

# %% [markdown]
# ***

# %% [markdown]
# Related Question 2: Does your zip code wealth change the availability of what networks of coverage you have access to?
#
# Business Justification: This is important to know because then Delta Dental can understand that they need to discuss with the dentists in those zip codes that may be lacking some of the network coverages that are offered in order to better accomadate the residents of the zip codes.
#
# Features Used: VIEW, CTE, Window Function, JOIN, GROUP BY
# (First query is my view and the next is the actual query)

# %%
# %%sql
# CREATE VIEW all_networks AS
# SELECT
#     DISTINCT networks,
#     zip_code,
# CASE
#     WHEN zip_code LIKE '94%' THEN 'High_Income_Zip'
# WHEN zip_code LIKE '93%' THEN 'Low_Income_Zip'
# END AS Zip_Category
# FROM lowIncome_zip
# UNION ALL
# SELECT
#     DISTINCT networks,
#     zip_code,
# CASE
#     WHEN zip_code LIKE '94%' THEN 'High_Income_Zip'
# WHEN zip_code LIKE '93%' THEN 'Low_Income_Zip'
# END AS Zip_Category
# FROM wealthy_zip
# ORDER BY zip_code;
# Out:
#  * mysql://admin:***@dnaka-sql-final.c8e00slqxvtw.us-east-1.rds.amazonaws.com/sql_final_project
# 0 rows affected.
# []

# %%
# %%sql
# WITH avg_median_income AS (
#     SELECT
#         AVG(median_household_income) AS avg_income,
#         zip_code
#     FROM zip_demographics
#     GROUP BY zip_code
# )
# SELECT
#     DENSE_RANK() OVER (
#         PARTITION BY Zip_Category
#         ORDER BY avg_income DESC
#     ) AS rank_avg_median_income,
#     zd.zip_code,
#     networks,
#     Zip_Category,
#     ROUND(avg_income) AS avg_median_income_by_zip
# FROM avg_median_income ami
# JOIN all_networks an
#     ON ami.zip_code = an.zip_code
# JOIN zip_demographics zd
#     ON an.zip_code = zd.zip_code;
# Out:
#  * mysql://admin:***@dnaka-sql-final.c8e00slqxvtw.us-east-1.rds.amazonaws.com/sql_final_project
# 49 rows affected.
# [(1, '94027', 'Delta Dental Premier', 'High_Income_Zip', Decimal('220583')),
#  (1, '94027', 'Delta Dental PPO, Delta Dental Premier', 'High_Income_Zip', Decimal('220583')),
#  (2, '94062', 'Delta Dental PPO, Delta Dental Premier', 'High_Income_Zip', Decimal('125060')),
#  (2, '94062', 'Delta Dental Premier', 'High_Income_Zip', Decimal('125060')),
#  (2, '94062', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', 'High_Income_Zip', Decimal('125060')),
#  (3, '94301', 'Delta Dental Premier', 'High_Income_Zip', Decimal('122473')),
#  (3, '94301', 'Delta Dental PPO, Delta Dental Premier', 'High_Income_Zip', Decimal('122473')),
#  (3, '94301', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', 'High_Income_Zip', Decimal('122473')),
#  (4, '94070', 'Delta Dental PPO, Delta Dental Premier', 'High_Income_Zip', Decimal('117679')),
#  (4, '94070', 'Delta Dental Premier', 'High_Income_Zip', Decimal('117679')),
#  (5, '94025', 'Delta Dental PPO, Delta Dental Premier', 'High_Income_Zip', Decimal('115444')),
#  (5, '94025', 'Delta Dental Premier', 'High_Income_Zip', Decimal('115444')),
#  (6, '94306', 'Delta Dental Premier', 'High_Income_Zip', Decimal('110580')),
#  (6, '94306', 'Delta Dental PPO, Delta Dental Premier', 'High_Income_Zip', Decimal('110580')),
#  (7, '94303', 'Delta Dental PPO, Delta Dental Premier', 'High_Income_Zip', Decimal('80127')),
#  (7, '94303', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', 'High_Income_Zip', Decimal('80127')),
#  (8, '94061', 'Delta Dental PPO, Delta Dental Premier', 'High_Income_Zip', Decimal('79833')),
#  (8, '94061', 'Delta Dental Premier', 'High_Income_Zip', Decimal('79833')),
#  (9, '94063', 'Delta Dental PPO, Delta Dental Premier', 'High_Income_Zip', Decimal('52818')),
#  (9, '94063', 'Delta Dental Premier', 'High_Income_Zip', Decimal('52818')),
#  (9, '94063', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', 'High_Income_Zip', Decimal('52818')),
#  (1, '93711', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', 'Low_Income_Zip', Decimal('65678')),
#  (1, '93711', 'Delta Dental Premier', 'Low_Income_Zip', Decimal('65678')),
#  (1, '93711', 'Delta Dental PPO, Delta Dental Premier', 'Low_Income_Zip', Decimal('65678')),
#  (2, '93704', 'Delta Dental Premier', 'Low_Income_Zip', Decimal('45844')),
#  (2, '93704', 'Delta Dental PPO, Delta Dental Premier', 'Low_Income_Zip', Decimal('45844')),
#  (3, '93727', 'Delta Dental PPO, Delta Dental Premier', 'Low_Income_Zip', Decimal('45760')),
#  (3, '93727', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', 'Low_Income_Zip', Decimal('45760')),
#  (3, '93727', 'Delta Dental Premier', 'Low_Income_Zip', Decimal('45760')),
#  (4, '93710', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', 'Low_Income_Zip', Decimal('42286')),
#  (4, '93710', 'Delta Dental PPO, Delta Dental Premier', 'Low_Income_Zip', Decimal('42286')),
#  (4, '93710', 'Delta Dental Premier', 'Low_Income_Zip', Decimal('42286')),
#  (5, '93612', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', 'Low_Income_Zip', Decimal('39801')),
#  (5, '93612', 'Delta Dental Premier', 'Low_Income_Zip', Decimal('39801')),
#  (5, '93612', 'Delta Dental PPO, Delta Dental Premier', 'Low_Income_Zip', Decimal('39801')),
#  (6, '93726', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', 'Low_Income_Zip', Decimal('32796')),
#  (6, '93726', 'Delta Dental PPO, Delta Dental Premier', 'Low_Income_Zip', Decimal('32796')),
#  (6, '93726', 'Delta Dental Premier', 'Low_Income_Zip', Decimal('32796')),
#  (7, '93705', 'Delta Dental PPO, Delta Dental Premier', 'Low_Income_Zip', Decimal('32485')),
#  (8, '93728', 'Delta Dental Premier', 'Low_Income_Zip', Decimal('32215')),
#  (8, '93728', 'Delta Dental PPO, Delta Dental Premier', 'Low_Income_Zip', Decimal('32215')),
#  (9, '93706', 'Delta Dental PPO, Delta Dental Premier', 'Low_Income_Zip', Decimal('29275')),
#  (10, '93703', 'Delta Dental PPO, Delta Dental Premier', 'Low_Income_Zip', Decimal('28663')),
#  (10, '93703', 'Delta Dental Premier', 'Low_Income_Zip', Decimal('28663')),
#  (11, '93701', 'Delta Dental PPO, Delta Dental Premier', 'Low_Income_Zip', Decimal('20201')),
#  (12, '93721', 'Delta Dental PPO, Delta Dental Premier', 'Low_Income_Zip', Decimal('16597')),
#  (12, '93721', 'Delta Dental Premier', 'Low_Income_Zip', Decimal('16597')),
#  (12, '93721', 'DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', 'Low_Income_Zip', Decimal('16597')),
#  (12, '93721', 'Delta Dental PPO, Delta Dental Premier, DeltaCare USA, DeltaCare USA Individual, DeltaCare USA Medicare, DeltaCare USA Connect', 'Low_Income_Zip', Decimal('16597'))]

# %% [markdown]
# Recommendation: I would recommmend that nothing changes in terms of the networks that are available in each zip code as in each, low income zip and high income zip, there is at least one of every network available at Delta Dental. These zip codes are within a 5 mile radius of each other and therefore accessible by anyone living in any of these zip codes.
